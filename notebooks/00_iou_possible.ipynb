# %%
from robot_utils.robot_data.img_data import ImgData
import matplotlib.pyplot as plt

# %%
bag = "/home/masonbp/data/west_point_2023/1117_03_loc_tower_loop_far_side_loop_o3_CW/align.bag"
img_data = ImgData(
        data_file=bag,
        file_type='bag',
        topic="/acl_jackal2/forward/color/image_raw/compressed",
        time_tol=.05,
        t0=0
    )

# %%
fig, ax = plt.subplots(1,2)
img1 = img_data.img(100)
img2 = img_data.img(100.1)
ax[0].imshow(img1[...,::-1])
ax[0].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
ax[1].imshow(img2[...,::-1])
ax[1].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)

# %%
fig, ax = plt.subplots(1,2)
img1 = img_data.img(100)
img2 = img_data.img(100.1)
ax[0].imshow(img1[...,::-1][200:400, 0:200,:])
ax[0].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
ax[1].imshow(img2[...,::-1][200:400, 0:200,:])
ax[1].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)

# %%
fig, ax = plt.subplots(1,3)
img1 = img_data.img(100)
img2 = img_data.img(100.1)
img3 = img_data.img(100.2)
ax[0].imshow(img1[...,::-1][225:275, 50:100,:])
ax[0].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
ax[1].imshow(img2[...,::-1][225:275, 50:100,:])
ax[1].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
ax[2].imshow(img3[...,::-1][225:275, 50:100,:])
ax[2].tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
